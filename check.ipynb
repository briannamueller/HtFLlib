# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn
# Out:
# zsh:1: command not found: pip

# %%
import pandas as pd

results_dict = {
    "FedDES": [0.7470, 0.7992, 0.8669, 0.6406, 0.9135, 0.7201, 0.7347, 0.6026, 0.8113, 0.6706, 0.6868, 0.7114, 0.7469, 0.8254, 0.6293, 0.6860, 0.6111, 0.7435, 0.7069, 0.7662],
    "local": [0.7343, 0.6811, 0.8582, 0.5743, 0.8876, 0.7019, 0.5401, 0.5792, 0.7291, 0.5736, 0.6263, 0.6227, 0.7125, 0.7989, 0.5691, 0.6295, 0.4943, 0.7204, 0.6726, 0.7415],
    "global_ens": [0.5600, 0.3727, 0.4182, 0.5020, 0.3656, 0.3856, 0.4389, 0.4584, 0.2837, 0.4482, 0.4947, 0.4217, 0.3563, 0.4573, 0.3919, 0.4380, 0.4521, 0.4659, 0.5260, 0.4108],
    "FedGH": [0.7746, 0.7743, 0.8741, 0.5221, 0.8876, 0.7513, 0.6450, 0.5935, 0.7869, 0.5084, 0.6655, 0.6741, 0.7203, 0.7780, 0.4894, 0.7231, 0.5728, 0.7465, 0.7033, 0.6908],
    "FedKD": [0.7805, 0.7703, 0.8553, 0.5422, 0.8750, 0.7418, 0.6374, 0.5545, 0.7689, 0.4833, 0.6779, 0.6554, 0.6766, 0.7799, 0.5398, 0.7190, 0.4923, 0.6824, 0.6868, 0.6338],
    "FedProto": [0.7707, 0.7310, 0.8553, 0.5141, 0.8986, 0.7782, 0.5859, 0.5701, 0.7843, 0.4649, 0.6637, 0.6332, 0.6719, 0.7609, 0.5431, 0.7107, 0.5383, 0.7044, 0.6761, 0.6631],
    "FedTPG": [0.7726, 0.7612, 0.8958, 0.5602, 0.9088, 0.7721, 0.6546, 0.6039, 0.8100, 0.5368, 0.6423, 0.7161, 0.7234, 0.7932, 0.5382, 0.6488, 0.5172, 0.7545, 0.6939, 0.7169],
    "FML": [0.7697, 0.7861, 0.8741, 0.5562, 0.8899, 0.7678, 0.6183, 0.5909, 0.7792, 0.4783, 0.6833, 0.6495, 0.7203, 0.7723, 0.5447, 0.7107, 0.5345, 0.7164, 0.6915, 0.6862],
    "LG-FedAvg": [0.7746, 0.8005, 0.8625, 0.5201, 0.8813, 0.7652, 0.6107, 0.5922, 0.7972, 0.4950, 0.6441, 0.6963, 0.7141, 0.8197, 0.5366, 0.6997, 0.5077, 0.7275, 0.7009, 0.7169]
}

# Create dataframe with client_id in the first column
df = pd.DataFrame(results_dict)
df.insert(0, "client_id", range(len(df)))

print(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       3 results_dict = {
#       4     "FedDES": [0.7470, 0.7992, 0.8669, 0.6406, 0.9135, 0.7201, 0.7347, 0.6026, 0.8113, 0.6706, 0.6868, 0.7114, 0.7469, 0.8254, 0.6293, 0.6860, 0.6111, 0.7435, 0.7069, 0.7662],
#       5     "local": [0.7343, 0.6811, 0.8582, 0.5743, 0.8876, 0.7019, 0.5401, 0.5792, 0.7291, 0.5736, 0.6263, 0.6227, 0.7125, 0.7989, 0.5691, 0.6295, 0.4943, 0.7204, 0.6726, 0.7415],
#    (...)
#      12     "LG-FedAvg": [0.7746, 0.8005, 0.8625, 0.5201, 0.8813, 0.7652, 0.6107, 0.5922, 0.7972, 0.4950, 0.6441, 0.6963, 0.7141, 0.8197, 0.5366, 0.6997, 0.5077, 0.7275, 0.7009, 0.7169]
#      13 }
#      15 # Create dataframe with client_id in the first column
#
# ModuleNotFoundError: No module named 'pandas'
